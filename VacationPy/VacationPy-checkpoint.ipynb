# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from config import gkey

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities_df = pd.read_csv("../output_data/cities.csv")
cities_df
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Morris  40.8334  -74.5329     50.09        83          90        1.01
# 1       Jumla  29.2747   82.1838     51.40        90           5        3.62
# 2        Brae  60.3964   -1.3530     51.71        87         100       25.17
# 3      Beloha -25.1667   45.0500     86.49        36          49       14.88
# 4       Kiama -34.6833  150.8667     65.68        99          82        6.89
# ..        ...      ...       ...       ...       ...         ...         ...
# 556   Houston  29.7633  -95.3633     74.89        90           1        1.99
# 557  Flinders -34.5833  150.8552     66.20        92          56        6.38
# 558    Panabá  21.2833  -88.2667     76.39        90          88        4.76
# 559   The Pas  53.8251 -101.2541     33.82       100          90        8.05
# 560    Shīeli  44.1667   66.7500     51.96        32          23        5.99
#
#            Date
# 0    1634993719
# 1    1634994013
# 2    1634993610
# 3    1634994015
# 4    1634993538
# ..          ...
# 556  1634993502
# 557  1634994237
# 558  1634994238
# 559  1634994238
# 560  1634994239
#
# [561 rows x 8 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=gkey)

# %%
locations = cities_df [["Lat", "Lng"]]
humidity = cities_df["Humidity"].astype(float)
#heatmap
fig= gmaps.figure(center=[0,0], zoom_level=2)
                  
#heatlayer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                               dissipating=False, max_intensity=100,
                               point_radius = 4)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
weather_city_df = cities_df.loc[(cities_df["Wind Speed"]<=10) & (cities_df['Cloudiness']== 0) & (cities_df['Max Temp']>=70) & (cities_df['Max Temp'] <= 80)].dropna()
weather_city_df
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 70    Carmo do Cajuru -20.1842 -44.7711     78.58        59           0
# 86         Abu Samrah  35.3029  37.1841     78.12        27           0
# 150          Pāsighāt  28.0667  95.3333     71.98        92           0
# 166   Tiznit Province  29.5833  -9.5000     77.50        38           0
# 368             Belen  36.4891  36.2233     71.04        30           0
# 502  La Seyne-sur-Mer  43.0982   5.8847     74.25        61           0
# 535         Myitkyina  25.3833  97.4000     74.03        82           0
#
#      Wind Speed        Date
# 70         8.19  1634994039
# 86         3.31  1634994043
# 150        2.98  1634994064
# 166        7.96  1634993488
# 368        6.22  1634994157
# 502        1.99  1634994214
# 535        1.01  1634994228

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#create variable
hotel_df = weather_city_df.reset_index(drop=True)

#add column "Hotel Name"
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Carmo do Cajuru -20.1842 -44.7711     78.58        59           0
# 1        Abu Samrah  35.3029  37.1841     78.12        27           0
# 2          Pāsighāt  28.0667  95.3333     71.98        92           0
# 3   Tiznit Province  29.5833  -9.5000     77.50        38           0
# 4             Belen  36.4891  36.2233     71.04        30           0
# 5  La Seyne-sur-Mer  43.0982   5.8847     74.25        61           0
# 6         Myitkyina  25.3833  97.4000     74.03        82           0
#
#    Wind Speed        Date Hotel Name
# 0        8.19  1634994039
# 1        3.31  1634994043
# 2        2.98  1634994064
# 3        7.96  1634993488
# 4        6.22  1634994157
# 5        1.99  1634994214
# 6        1.01  1634994228

# %%
#Set parameters to search for hotels with 5000 meters.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {"type" : 'hotel', 
              'radius': 5000, 
              'key': gkey}

#Hit the Google Places API for each city's coordinates.
for index, row in hotel_df.iterrows():
    lat = row['Lat']
    lng = row['Lng']
    nameofcity = row['City']
    params['location'] = f'{lat},{lng}'

    #Store the first Hotel result into the DataFrame.
    hotel_name = requests.get(base_url, params=params)
    hotel_name = hotel_name.json()
    print(json.dumps(hotel_name, indent=4, sort_keys=True))
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]['name']
    except (KeyError, IndexError):
        print("Missing field/result...skipping.")
hotel_df
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEDKsJ-okCpACRutSlnB5uuCb857nlLtm6PEczp5frl-rvK_sPVyhnYh_uoP4dN4GoOEFuTAZBVSb2NGrwxWePcuu5tf8K1ED4JBuVOY5RJpMmOshHRJ7Yhhe89om8KV852xMtivc2YSiQxvo5fiynF_zVy2O66J22qGC7uIKZrW3IY3rDhEz8aU3AP_vMko8UuclW1DiF9f8qAlmK_xlsQ-z7qy2h745B0qtYuurMd-m0bNWaJ08AELTb7WTHJLIs_2-OHIPnAihHwvjYsSpwlRENZmqGfrJLLkwG-A__LAr9bAs1ugv3NueKetFAchtp7kovwEyGzX_8wnF1dX-CwWBaIW2R0cbJ2adDkz5gEuJaWsmTcueaTILGOPiS2BowDr4xbRr7zNsL02UYFN9BrleDdclZFsVa5w75Vh9yviY8RFqm8PLA",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -20.1847973,
#                     "lng": -44.7714395
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.17074528736678,
#                         "lng": -44.74529666145065
#                     },
#                     "southwest": {
#                         "lat": -20.21175240679344,
#                         "lng": -44.79258908523476
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Carmo do Cajuru",
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107336787169961723807\">Claudiney Coelho</a>"
#                     ],
#                     "photo_reference": "Aap_uEB-U3-ELk10SJArOfuB0xQd8Ftt6M90YBfh_2ztNPg7KfEQMFLC4lTq2o71XXKsT06z67Vc1k8sFIRTbvY9_2ZBMZJ6XAlH-PGx5vgG4xDdLIcGZs-6DGZzqrsicQ25wT5tlthLlRK0ezK7SRDrxUHIjm7BPPJGXx39y4asdq4z8Gix",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJxR7LovK5oAAROe0PNtSuuSU",
#             "reference": "ChIJxR7LovK5oAAROe0PNtSuuSU",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1872785,
#                     "lng": -44.7727364
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.18596326970849,
#                         "lng": -44.7714208697085
#                     },
#                     "southwest": {
#                         "lat": -20.1886612302915,
#                         "lng": -44.7741188302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet",
#             "name": "C\u00e2mara Municipal de Carmo do Cajuru",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3982,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104513275308163612389\">C\u00e2mara Municipal de Carmo do Cajuru</a>"
#                     ],
#                     "photo_reference": "Aap_uED6K29OxF-ovea9k92XEcWDB_68QjLarnEeur-K59dTYgFGyW2k-GuvSSyEhJlfrhk8_YorO3sr7iFfDt_h3a7a05fP5fxgvjKg77vjDZRN9TVDd_XwvBthY-TXVB7DTVkq3f5YzrzlSEAIDyPN3LObDwMOgwvEmALHSuivitHUKQeq",
#                     "width": 5372
#                 }
#             ],
#             "place_id": "ChIJY6hrNPK5oAAR6MFdQyG48as",
#             "plus_code": {
#                 "compound_code": "R67G+3W Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR67G+3W"
#             },
#             "rating": 5,
#             "reference": "ChIJY6hrNPK5oAAR6MFdQyG48as",
#             "scope": "GOOGLE",
#             "types": [
#                 "local_government_office",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Avenida Jos\u00e9 Marra da Silva, 175 - Centro, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1845435,
#                     "lng": -44.77096939999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1832813197085,
#                         "lng": -44.7695074197085
#                     },
#                     "southwest": {
#                         "lat": -20.1859792802915,
#                         "lng": -44.7722053802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet",
#             "name": "Igreja Matriz Nossa Senhora do Carmo",
#             "photos": [
#                 {
#                     "height": 2992,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111181006616513535388\">Ivaniza Miranda</a>"
#                     ],
#                     "photo_reference": "Aap_uECjCkloqoLH3-sXXfINWL5fCHCuIxQr2j-JUnIBR03-wPEVjNoeCNt77hAYXtIy7Arxkcr7obzxrtvyawTww5NwkoGHq3_BVIT4RiSjN78RjLdiAZCVGLBYn8M6RNChGXIqGTCCw8z_P9fvpKuRaaxRTl-ckjw4lSzQQ9mK_upKlzFE",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJY6hrNPK5oAARK3uKFVfGaoo",
#             "plus_code": {
#                 "compound_code": "R68H+5J Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR68H+5J"
#             },
#             "rating": 4.8,
#             "reference": "ChIJY6hrNPK5oAARK3uKFVfGaoo",
#             "scope": "GOOGLE",
#             "types": [
#                 "church",
#                 "place_of_worship",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 315,
#             "vicinity": "Pra\u00e7a Vig\u00e1rio Jos\u00e9 Alexandre, S/N, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1869625,
#                     "lng": -44.77002299999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1855854197085,
#                         "lng": -44.7686450697085
#                     },
#                     "southwest": {
#                         "lat": -20.18828338029151,
#                         "lng": -44.7713430302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Aroma Cyber Caf\u00e9",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJ-Wo7X_G5oAAROnpnvJhkjq8",
#             "plus_code": {
#                 "compound_code": "R67H+6X Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR67H+6X"
#             },
#             "rating": 5,
#             "reference": "ChIJ-Wo7X_G5oAAROnpnvJhkjq8",
#             "scope": "GOOGLE",
#             "types": [
#                 "electrician",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Rua Jos\u00e9 Dem\u00e9trio Coelho, 960, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1851713,
#                     "lng": -44.775245
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1837738697085,
#                         "lng": -44.7738915197085
#                     },
#                     "southwest": {
#                         "lat": -20.1864718302915,
#                         "lng": -44.7765894802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Mg tecidos",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117465908793585047223\">MG Tecidos</a>"
#                     ],
#                     "photo_reference": "Aap_uEDWgork6-6hyLeRExboIvAmC8DoYyZOk1FjK-ziR3wOQjXvRRqVLQt2gCMCea1EJhqTEAS7nMtt1sfteQffquWEYt8QrBVTFhr4VURtgUUief93QQhFGUZoWhORrydMyKDBZLzHlBC0FuA3GR7jTs_GI7fBXM6IveunXTJanko8gmKG",
#                     "width": 5184
#                 }
#             ],
#             "place_id": "ChIJBxRQle6loAARqkmHIteE1JA",
#             "plus_code": {
#                 "compound_code": "R67F+WW Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR67F+WW"
#             },
#             "rating": 5,
#             "reference": "ChIJBxRQle6loAARqkmHIteE1JA",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "Rua Jos\u00e9 Dem\u00e9trio Coelho, 266, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.18474149999999,
#                     "lng": -44.77358390000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.18332896970849,
#                         "lng": -44.77223556970851
#                     },
#                     "southwest": {
#                         "lat": -20.1860269302915,
#                         "lng": -44.77493353029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "CCAA Carmo do Cajuru",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1334,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113583509739008044730\">CCAA Carmo do Cajuru</a>"
#                     ],
#                     "photo_reference": "Aap_uEDTro7ewtN3VMQaLl3YmNRjA177ucIJHIZ4ZTpOdZewAvyaV7aqAEFVdxZ3zY9eD9atV4eH5RgK7nvqFGskLBZaX7H-264LjeHoCt2gcNl0zrBMkkyw-fPycuqiVsTWFEfEnNUaVwlu4KEQpgGEwmRnoQlnwR9F0PCMJdzAda1XHs4",
#                     "width": 750
#                 }
#             ],
#             "place_id": "ChIJY6hrNPK5oAARVVJrYsDpNd0",
#             "plus_code": {
#                 "compound_code": "R68G+4H Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR68G+4H"
#             },
#             "rating": 4.2,
#             "reference": "ChIJY6hrNPK5oAARVVJrYsDpNd0",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "Pra\u00e7a Presidente Get\u00falio Vargas, 356 - Centro, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1926504,
#                     "lng": -44.7620727
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1912257697085,
#                         "lng": -44.7606467197085
#                     },
#                     "southwest": {
#                         "lat": -20.19392373029151,
#                         "lng": -44.7633446802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "Ee Vig\u00e1rio Jos\u00e9 Alexandre",
#             "place_id": "ChIJY6hrNPK5oAARWfNHFQAeP6g",
#             "plus_code": {
#                 "compound_code": "R64Q+W5 Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR64Q+W5"
#             },
#             "rating": 4.5,
#             "reference": "ChIJY6hrNPK5oAARWfNHFQAeP6g",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "Rua S\u00e3o Francisco de Assis, 30 - Nossa Senhora Do Carmo, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.190104,
#                     "lng": -44.76983099999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1887424197085,
#                         "lng": -44.7684697697085
#                     },
#                     "southwest": {
#                         "lat": -20.1914403802915,
#                         "lng": -44.77116773029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Funer\u00e1ria Jada Pax",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106222767784689399179\">Funer\u00e1ria Jadapax - Carmo do Cajuru</a>"
#                     ],
#                     "photo_reference": "Aap_uEB6dMWhxfp_9uL4M1c_Ruhrdpm6v3tgk14fTS8vhfK0P2fpDZ7RW5tqQGTPbY9ZGqlIdzJ1uoq1Yqo8lB0a6SLnTwTXYWvmzE9lI4gLO9jeFtv5p_s0xuSm9SYEjJtQ-YZ4nwV95iBzejNFA2ib6RO7iTcLAMc2SGoEwFNYpOdAmSRU",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJY6hrNPK5oAAR_Eob0JGc-oI",
#             "plus_code": {
#                 "compound_code": "R65J+X3 Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR65J+X3"
#             },
#             "rating": 5,
#             "reference": "ChIJY6hrNPK5oAAR_Eob0JGc-oI",
#             "scope": "GOOGLE",
#             "types": [
#                 "funeral_home",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Avenida Jos\u00e9 Marra da Silva, 620, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.161923,
#                     "lng": -44.76319549999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1606289197085,
#                         "lng": -44.76166101970851
#                     },
#                     "southwest": {
#                         "lat": -20.1633268802915,
#                         "lng": -44.7643589802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Look Design",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117283197976365296312\">Look Design</a>"
#                     ],
#                     "photo_reference": "Aap_uEDRtS9qRV-z2B7NgxCRo7j18g8VygLRM2r-Ix4E2PffnM9IaQoI3SynV30KzQQgAdGKbIiN_t_A9ze-JYO4W_MJr5hKwDudlwCAapE0zb2Vt7zXzR1hEHco8oTdlleV7M97-eXQ390vTTtH_e3xGF_gksRtMIHSIbVWJt1ppBnk7xp5",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJY6hrNPK5oAAR15lI89NBOpU",
#             "plus_code": {
#                 "compound_code": "R6QP+6P Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR6QP+6P"
#             },
#             "rating": 4.4,
#             "reference": "ChIJY6hrNPK5oAAR15lI89NBOpU",
#             "scope": "GOOGLE",
#             "types": [
#                 "furniture_store",
#                 "home_goods_store",
#                 "general_contractor",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "Avenida Progresso, 821 - Distrito Industrial II, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1904269,
#                     "lng": -44.7658126
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1891287197085,
#                         "lng": -44.76451456970851
#                     },
#                     "southwest": {
#                         "lat": -20.1918266802915,
#                         "lng": -44.7672125302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Laborat\u00f3rio Central",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 958,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107155786432719528605\">Laborat\u00f3rio Central</a>"
#                     ],
#                     "photo_reference": "Aap_uEDEct6OKXLeVOBTik9LMonmBjMxbGeHTqQn0SdX6muuBdP2DJKg6P_Oi2yHUAyQuCY_9GT6707zJLqgxaNhsjXoFrLt6bePEm-xGL5W2Vc6rFLuxOu7hO4aQ_6egqT7SoJlV9wok9R68OX5i7t8VVtkueWPzPLT4hAGhXuNS5_065C7",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJY6hrNPK5oAARFdfbHVDhQH4",
#             "plus_code": {
#                 "compound_code": "R65M+RM Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR65M+RM"
#             },
#             "rating": 5,
#             "reference": "ChIJY6hrNPK5oAARFdfbHVDhQH4",
#             "scope": "GOOGLE",
#             "types": [
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Rua Jos\u00e9 Dem\u00e9trio Coelho, 831, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.191663,
#                     "lng": -44.7668378
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1902281197085,
#                         "lng": -44.7654047697085
#                     },
#                     "southwest": {
#                         "lat": -20.1929260802915,
#                         "lng": -44.7681027302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Urnas El Shaday",
#             "place_id": "ChIJY6hrNPK5oAAROaQRAozq7UI",
#             "plus_code": {
#                 "compound_code": "R65M+87 Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR65M+87"
#             },
#             "reference": "ChIJY6hrNPK5oAAROaQRAozq7UI",
#             "scope": "GOOGLE",
#             "types": [
#                 "funeral_home",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida Circular, 525, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1787205,
#                     "lng": -44.7872397
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.17734606970849,
#                         "lng": -44.7858797197085
#                     },
#                     "southwest": {
#                         "lat": -20.1800440302915,
#                         "lng": -44.7885776802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Metal\u00fargica Carola Ltda",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106641127932137847142\">Metal\u00fargica Carola Ltda</a>"
#                     ],
#                     "photo_reference": "Aap_uEBXvSl5aHjCqmk4PJD5kBGWXu8UvW4jjP8jWO3hmXnhcXZF80k5yZQdPYyOLJiNA7p6WuGd7WTzegRUupBY4fk5HvDC2Upgdod1v-N7ExAXB0dH_fX-uR7iw3AX1cfXVzaQYAvkHoyLhUkAe3kqWugBhdstXtTapk06NGMFEk233cXj",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJY6hrNPK5oAARu3Ldy4jB3ik",
#             "plus_code": {
#                 "compound_code": "R6C7+G4 Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR6C7+G4"
#             },
#             "rating": 5,
#             "reference": "ChIJY6hrNPK5oAARu3Ldy4jB3ik",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Rua Oito, 30 - Jd Alvorada, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.191663,
#                     "lng": -44.7668378
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1902281197085,
#                         "lng": -44.7654047697085
#                     },
#                     "southwest": {
#                         "lat": -20.1929260802915,
#                         "lng": -44.7681027302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet",
#             "name": "Pol\u00edcia Militar do Est de Minas Gerais",
#             "place_id": "ChIJY6hrNPK5oAAR1M0UR0gmx_A",
#             "plus_code": {
#                 "compound_code": "R65M+87 Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR65M+87"
#             },
#             "reference": "ChIJY6hrNPK5oAAR1M0UR0gmx_A",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Rua Cust\u00f3dio Nogueira Gontijo, 270, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1831171,
#                     "lng": -44.7785089
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1816537197085,
#                         "lng": -44.7771194197085
#                     },
#                     "southwest": {
#                         "lat": -20.1843516802915,
#                         "lng": -44.7798173802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "EE S\u00e3o Francisco De Assis",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJ9VobSBy6oAAR76kUIyvzxAQ",
#             "plus_code": {
#                 "compound_code": "R68C+QH Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR68C+QH"
#             },
#             "rating": 4,
#             "reference": "ChIJ9VobSBy6oAAR76kUIyvzxAQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "Rua Sete, 5s - n5, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.191663,
#                     "lng": -44.7668378
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1902281197085,
#                         "lng": -44.7654047697085
#                     },
#                     "southwest": {
#                         "lat": -20.1929260802915,
#                         "lng": -44.7681027302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Classic M\u00f3veis",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJY6hrNPK5oAARQPcwNqPz3H0",
#             "plus_code": {
#                 "compound_code": "R65M+87 Carmo do Cajuru, State of Minas Gerais, Brazil",
#                 "global_code": "58FQR65M+87"
#             },
#             "reference": "ChIJY6hrNPK5oAARQPcwNqPz3H0",
#             "scope": "GOOGLE",
#             "types": [
#                 "furniture_store",
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "vicinity": "Brazil"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1859328,
#                     "lng": -44.7701969
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1846138197085,
#                         "lng": -44.7688840197085
#                     },
#                     "southwest": {
#                         "lat": -20.18731178029151,
#                         "lng": -44.7715819802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "O Botic\u00e1rio",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113360637195521699684\">O Botic\u00e1rio</a>"
#                     ],
#                     "photo_reference": "Aap_uEDv8qDa8vAw_HhYp__4xHiW6QNSezr0F8Ff7EsxiXuZcVPHPSkKnSyBQr_CJBPH5kgqkzdqoLeBALeD7VP8liJoAUQUjSwkHQDQGUQCs3mcbXxybBw5Ik1RBgfN8ovdj0Vg_uwD7AVhCRwUMduHL84CmMdGc8RDsn6UDk5L9zzB_pjA",
#                     "width": 1980
#                 }
#             ],
#             "place_id": "ChIJd_Um2Gm0oAARmsuj_dzyhq0",
#             "plus_code": {
#                 "compound_code": "R67H+JW Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR67H+JW"
#             },
#             "rating": 4.8,
#             "reference": "ChIJd_Um2Gm0oAARmsuj_dzyhq0",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 39,
#             "vicinity": "Rua Tiradentes, 331 - Centro, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1893567,
#                     "lng": -44.76676779999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1879972697085,
#                         "lng": -44.7654364697085
#                     },
#                     "southwest": {
#                         "lat": -20.1906952302915,
#                         "lng": -44.7681344302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Mobiliadora \u00c1guia",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJY6hrNPK5oAARVax1w4tmjO8",
#             "plus_code": {
#                 "compound_code": "R66M+77 Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR66M+77"
#             },
#             "rating": 5,
#             "reference": "ChIJY6hrNPK5oAARVax1w4tmjO8",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Rua \u00c1guia, 93 - Centro, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.1854391,
#                     "lng": -44.7705721
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1841411697085,
#                         "lng": -44.7692845697085
#                     },
#                     "southwest": {
#                         "lat": -20.1868391302915,
#                         "lng": -44.77198253029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/bank-intl_pinlet",
#             "name": "BANCO DO BRASIL - CARMO DO CAJURU - Ag\u00eancia 1749",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102681476305255310910\">Daniel Eug\u00eanio</a>"
#                     ],
#                     "photo_reference": "Aap_uEAi5H_qjYs4ZJgXe9vVpP8rYt7llF70EZnZ2bs724CCstGgxXAzpjq-LmmhRCW4UFVnuSfB1UrHptrBAlj517njQNJK8D5dkj7ZWOMygD5C2A8Mk8B45jU0Janr9GX3dQfQI_WmNMlXJREH0BizHN4On2QVGOZZyJh4W_HyIfcjA-ib",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJJy2InkIgogARhmBnnaIQQdE",
#             "plus_code": {
#                 "compound_code": "R67H+RQ Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR67H+RQ"
#             },
#             "rating": 2.4,
#             "reference": "ChIJJy2InkIgogARhmBnnaIQQdE",
#             "scope": "GOOGLE",
#             "types": [
#                 "bank",
#                 "atm",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "Rua Tiradentes, 261 - CENTRO, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.191663,
#                     "lng": -44.7668378
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1902281197085,
#                         "lng": -44.7654047697085
#                     },
#                     "southwest": {
#                         "lat": -20.1929260802915,
#                         "lng": -44.7681027302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "edson rocha",
#             "place_id": "ChIJ96drNPK5oAARm9Qn4acy3Ao",
#             "plus_code": {
#                 "compound_code": "R65M+87 Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR65M+87"
#             },
#             "reference": "ChIJ96drNPK5oAARm9Qn4acy3Ao",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Rua Firmino Lopes C\u00e2mara, 1196, Carmo do Cajuru"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.177458,
#                     "lng": -44.763389
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.1761777697085,
#                         "lng": -44.76205986970849
#                     },
#                     "southwest": {
#                         "lat": -20.1788757302915,
#                         "lng": -44.76475783029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Carmovart Ltda",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJY6hrNPK5oAARtp0CQvEiiAc",
#             "plus_code": {
#                 "compound_code": "R6FP+2J Carmo do Cajuru - State of Minas Gerais, Brazil",
#                 "global_code": "58FQR6FP+2J"
#             },
#             "rating": 5,
#             "reference": "ChIJY6hrNPK5oAARtp0CQvEiiAc",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Rua Sete, 285 - Dto Ind J A Nogueira, Carmo do Cajuru"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 35.3203237,
#                     "lng": 37.2048894
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.32510488263767,
#                         "lng": 37.21215248241005
#                     },
#                     "southwest": {
#                         "lat": 35.31379449678393,
#                         "lng": 37.19593045627117
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Suruj",
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108672083767378111716\">\u0623\u0628\u0640,\u0640\u0646\u0640,\u0640 \u0633\u0640,\u0640\u06c5\u0631\u064a\u0640,\u0640\u0622</a>"
#                     ],
#                     "photo_reference": "Aap_uED-VukoSBSFPeYUZIxnopcdZRah8d7dzLmhYKCkpqyqzhKYkodPrz1TYZ10GanqRuUvbI_VUOlt8dNfMgoW9Pa6lhVni9U4s2jexwDubell9WqcZ8C-tQDZaNNmoadoXYRnZXWBz8FKRyzr86YCt7qnp6D6Taa1R3KdW6sH6BTHQOop",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJBQl_gmbJJBURG_l4aOr_f9M",
#             "reference": "ChIJBQl_gmbJJBURG_l4aOr_f9M",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Suruj"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 35.3229164,
#                     "lng": 37.1992242
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.3244245802915,
#                         "lng": 37.2008642302915
#                     },
#                     "southwest": {
#                         "lat": 35.3217266197085,
#                         "lng": 37.1981662697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Parseckopen.tk Datacentrum",
#             "photos": [
#                 {
#                     "height": 718,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108490940809586601929\">\u0645\u0628\u0627\u0631\u0643 \u0627\u0628\u0648 \u062d\u0633\u064a\u0646</a>"
#                     ],
#                     "photo_reference": "Aap_uEAS_kPTXU4x1LDUCYS_PWX75YaOL0btaK9zLnC8AbbJidwFnK2HKy39X6MypMJdQrV-lLkWvU_P1qj73yKUcTF7Huhr8RCyBwETZszF6rgf-XTop7YBGsr2LI6F3xJNSINzTHM4H2wMghz8H5Yr8LpQTXIcT16lZknKPNJL7Je5Yx1k",
#                     "width": 706
#                 }
#             ],
#             "place_id": "ChIJD3b77WjJJBURCPHIRXUz1Q8",
#             "rating": 5,
#             "reference": "ChIJD3b77WjJJBURCPHIRXUz1Q8",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "85FX+5M9, Suruj"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 35.30195510000001,
#                     "lng": 37.1862678
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.30352703029151,
#                         "lng": 37.18763428029149
#                     },
#                     "southwest": {
#                         "lat": 35.30082906970851,
#                         "lng": 37.1849363197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#             "name": "\u0645\u062f\u0631\u0633\u0629 \u0627\u0644\u0648\u0633\u064a\u0637\u0629 \u0627\u0644\u0625\u0628\u062a\u062f\u0627\u0626\u064a\u0629",
#             "place_id": "ChIJCU36t_rJJBURYPhfkmt4ahs",
#             "plus_code": {
#                 "compound_code": "852P+QG \u0627\u0644\u0648\u0633\u064a\u0637\u0629\u060c Syria",
#                 "global_code": "8G7V852P+QG"
#             },
#             "reference": "ChIJCU36t_rJJBURYPhfkmt4ahs",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Unnamed Road, \u0627\u0644\u0648\u0633\u064a\u0637\u0629\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 35.3178856,
#                     "lng": 37.20250860000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.31921943029149,
#                         "lng": 37.2038639802915
#                     },
#                     "southwest": {
#                         "lat": 35.3165214697085,
#                         "lng": 37.2011660197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "\u0627\u0644\u062a\u0642\u064a \u0644\u0644\u0625\u062a\u0635\u0627\u0644\u0627\u062a",
#             "place_id": "ChIJK1ua6wLJJBUR6YWcWKSwSYc",
#             "plus_code": {
#                 "compound_code": "8693+52 Suruj, Syria",
#                 "global_code": "8G7V8693+52"
#             },
#             "reference": "ChIJK1ua6wLJJBUR6YWcWKSwSYc",
#             "scope": "GOOGLE",
#             "types": [
#                 "electronics_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "vicinity": "\u0637\u0631\u064a\u0642"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 35.3177791,
#                     "lng": 37.2035007
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.31915353029149,
#                         "lng": 37.2050144302915
#                     },
#                     "southwest": {
#                         "lat": 35.3164555697085,
#                         "lng": 37.2023164697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_islam-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_islam_pinlet",
#             "name": "Saddles Mosque",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 642,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104726953283808461019\">Ji\u0159\u00ed Horsk\u00fd</a>"
#                     ],
#                     "photo_reference": "Aap_uEAl6gJJrWjvnylnRkED6PSlW-68UCs1ZqXPK5ZuHe5B34AFi32KxWPGUJZrjAuZkVkS4-_p4jTDER2BvmL7jYTZCKA8Kuuqk6fgz-F2NE2blIDUWL_l38BwwlOniRGmbu9bGn77cdJjt6lCW73tLxGO9R0iIFi3tltBL2_0c4TKQPtZ",
#                     "width": 1000
#                 }
#             ],
#             "place_id": "ChIJ81E4rWXJJBURUX3flV25Uf4",
#             "rating": 5,
#             "reference": "ChIJ81E4rWXJJBURUX3flV25Uf4",
#             "scope": "GOOGLE",
#             "types": [
#                 "mosque",
#                 "place_of_worship",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "8693+4C6, Suruj"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 35.3184784,
#                     "lng": 37.2049813
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.3198920802915,
#                         "lng": 37.2062509302915
#                     },
#                     "southwest": {
#                         "lat": 35.3171941197085,
#                         "lng": 37.2035529697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/pharmacy-71.png",
#             "icon_background_color": "#F88181",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/pharmacy_pinlet",
#             "name": "\u0635\u064a\u062f\u0644\u064a\u0629 \u0645\u062d\u0645\u062f \u062e\u0645\u064a\u0633",
#             "place_id": "ChIJH32NF2TJJBURFJlfLKHmv4o",
#             "rating": 2.8,
#             "reference": "ChIJH32NF2TJJBURFJlfLKHmv4o",
#             "scope": "GOOGLE",
#             "types": [
#                 "pharmacy",
#                 "health",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "8693+9XX, Suruj"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 35.3186682,
#                     "lng": 37.2056775
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.3201458802915,
#                         "lng": 37.20675388029149
#                     },
#                     "southwest": {
#                         "lat": 35.3174479197085,
# ...
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "King Star Aluminium and Glass Myitkyina",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106881557471049147638\">David Moe</a>"
#                     ],
#                     "photo_reference": "Aap_uECD0fH1EnbCXb7j_oQe0gwDCQnHNCLfbVS7J-wvhYObD3djSdeq4vmVAEBid9YkBy25vWakKMMykBz8GtMV72tzriRrcOB3sg64-9OUr_TY_NTlkFtQBZ1tMN7ly9OTLkTnU7e9UH39Cs9H5QMe1WAWDVA_2JvvEpDEHxk9DfbTh7in",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJ8z9nhoF0MDcRyqakYIwBL08",
#             "rating": 5,
#             "reference": "ChIJ8z9nhoF0MDcRyqakYIwBL08",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "9CM2+Q22, Myitkyina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.38315,
#                     "lng": 97.398967
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.3844926802915,
#                         "lng": 97.40022428029151
#                     },
#                     "southwest": {
#                         "lat": 25.3817947197085,
#                         "lng": 97.3975263197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Neo Mobile - TrueMoney",
#             "place_id": "ChIJJSD76YF0MDcROBfbcbNMxM4",
#             "plus_code": {
#                 "compound_code": "99MX+7H Myitkyina, Myanmar (Burma)",
#                 "global_code": "7MQV99MX+7H"
#             },
#             "reference": "ChIJJSD76YF0MDcROBfbcbNMxM4",
#             "scope": "GOOGLE",
#             "types": [
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Aye Zayti 67, Myitkyina ., \u1019\u103c\u1005\u103a\u1000\u103c\u102e\u1038\u1014\u102c\u1038"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.3838903,
#                     "lng": 97.39915789999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.3853660802915,
#                         "lng": 97.4004976302915
#                     },
#                     "southwest": {
#                         "lat": 25.3826681197085,
#                         "lng": 97.39779966970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/bank-intl_pinlet",
#             "name": "KBZ Bank (Myitkyina Branch)",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJPwSqooF0MDcR7_zn43VF1T0",
#             "rating": 4.3,
#             "reference": "ChIJPwSqooF0MDcR7_zn43VF1T0",
#             "scope": "GOOGLE",
#             "types": [
#                 "bank",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "99MX+HM3, Myitkyina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.3819086,
#                     "lng": 97.3995569
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.3832593802915,
#                         "lng": 97.4009418802915
#                     },
#                     "southwest": {
#                         "lat": 25.3805614197085,
#                         "lng": 97.39824391970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Windy City Computer, CCTV, Mobile Sales and Services",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102816031046138561941\">Sanjay Kumar</a>"
#                     ],
#                     "photo_reference": "Aap_uEDRn_9YHYoF23MFfVENvnRgw3Leqe-6Yp5k-bOrMrguM4lIJ4l6UohDiL_bXOc4ex6xArnzZxTnj3IfzrIvzkY8TVvpVENnVIFaoY780lNsAxJiJ4arusFwkrEG3fA8WBhgivqVUTDNdMbiInGlZcjZmifAIjUj8FcEDySj4Rd2MJ4c",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJ-xEmHH5zMDcRxDwZy-ndKAk",
#             "plus_code": {
#                 "compound_code": "99JX+QR Myitkyina, Myanmar (Burma)",
#                 "global_code": "7MQV99JX+QR"
#             },
#             "rating": 5,
#             "reference": "ChIJ-xEmHH5zMDcRxDwZy-ndKAk",
#             "scope": "GOOGLE",
#             "types": [
#                 "shopping_mall",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Yadanar, Myitkyina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.3847044,
#                     "lng": 97.3998649
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.3861166802915,
#                         "lng": 97.4012103802915
#                     },
#                     "southwest": {
#                         "lat": 25.3834187197085,
#                         "lng": 97.3985124197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/bank-intl_pinlet",
#             "name": "Yoma Bank",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107810849744295713660\">Win Naing</a>"
#                     ],
#                     "photo_reference": "Aap_uEA2JGNWul255JLVkvkhyFw4TSdDaHGjI5GQH5IqcANBXzE2-7QHp3en1pGuWuB92G0-w1dTJbabrzpPbk5ZOrPoT6u7e21F07VFtveAAJwbSFCxlzkHtZejy8uFB_B86l5GoX4kJkjsCVSxlcbY0ce79R8yRAWCuQ66nCV0uEBYWYoq",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJd3bgg4F0MDcR6waU3GmkWF0",
#             "rating": 4.5,
#             "reference": "ChIJd3bgg4F0MDcR6waU3GmkWF0",
#             "scope": "GOOGLE",
#             "types": [
#                 "bank",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "99MX+VWQ, Myitkyina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.3837104,
#                     "lng": 97.3976947
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.38506368029151,
#                         "lng": 97.39907678029151
#                     },
#                     "southwest": {
#                         "lat": 25.3823657197085,
#                         "lng": 97.39637881970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "UMA SALUM FASHION SHOP",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJ2bhstYF0MDcRtTc8-XT6jEU",
#             "plus_code": {
#                 "compound_code": "99MX+F3 Myitkyina, Myanmar (Burma)",
#                 "global_code": "7MQV99MX+F3"
#             },
#             "rating": 5,
#             "reference": "ChIJ2bhstYF0MDcRtTc8-XT6jEU",
#             "scope": "GOOGLE",
#             "types": [
#                 "clothing_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Ta-Sa-Nya Building near YMCA Hall, \u1019\u103c\u1005\u103a\u1000\u103c\u102e\u1038\u1014\u102c\u1038"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.380396,
#                     "lng": 97.4012462
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.38174513029151,
#                         "lng": 97.4025970802915
#                     },
#                     "southwest": {
#                         "lat": 25.3790471697085,
#                         "lng": 97.3998991197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Yangon Store",
#             "place_id": "ChIJId9Pwn1zMDcRPTn4YCtoCHg",
#             "plus_code": {
#                 "compound_code": "9CJ2+5F Myitkyina, Myanmar (Burma)",
#                 "global_code": "7MQV9CJ2+5F"
#             },
#             "rating": 4.2,
#             "reference": "ChIJId9Pwn1zMDcRPTn4YCtoCHg",
#             "scope": "GOOGLE",
#             "types": [
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "wine maw street\u3001, Myitkyina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 25.3795426,
#                     "lng": 97.39928189999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.3808950302915,
#                         "lng": 97.40063068029151
#                     },
#                     "southwest": {
#                         "lat": 25.3781970697085,
#                         "lng": 97.39793271970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Sein Phone Myint Trading",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108074104710544813954\">Zaw Myint Lwin</a>"
#                     ],
#                     "photo_reference": "Aap_uEB0he39hbWMViqJPfdteor_gnM1rBqgUwVTjX8HUuZ8roRqI0r-PPspfPd_wReIAOOgFgyPmKjUADeaf0zrzPASkjzbcBMB3EMLX5yzhKUMtt0NppF1y1dWvJXVHqAB8dkwSRUAXk2mKMr__Sw3ZIMSf_zTDfNZ-rBJB5B_AyGrpUn4",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJFSUdZH5zMDcR7qwpfumfJnI",
#             "plus_code": {
#                 "compound_code": "99HX+RP Myitkyina, Myanmar (Burma)",
#                 "global_code": "7MQV99HX+RP"
#             },
#             "rating": 3.7,
#             "reference": "ChIJFSUdZH5zMDcR7qwpfumfJnI",
#             "scope": "GOOGLE",
#             "types": [
#                 "car_repair",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Unnamed Road, \u1019\u103c\u1005\u103a\u1000\u103c\u102e\u1038\u1014\u102c\u1038"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.324836,
#                     "lng": 97.4246158
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.36054723073588,
#                         "lng": 97.44632720748518
#                     },
#                     "southwest": {
#                         "lat": 25.31384755887427,
#                         "lng": 97.38624563938231
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Waimaw",
#             "photos": [
#                 {
#                     "height": 2909,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111191760689789236796\">Oo Nan</a>"
#                     ],
#                     "photo_reference": "Aap_uEDKio982YkM2KW2ohcdajRvWabEzbXRnSalUv8F6sbDjdYIwWEDnty-Wh3GnLEtUtBLN7WxZwLd3o6omD_0ezBScVJkiKhk0Xv7NrUWsHBPuBg34RMOD4PvAC53o6g-I89rthl7Sa468xWiA37VFLJhtTJoBHVZL1qTFCy-iaa9jBj_",
#                     "width": 3882
#                 }
#             ],
#             "place_id": "ChIJ32Ibfx9zMDcRX8lRSE59RrA",
#             "reference": "ChIJ32Ibfx9zMDcRX8lRSE59RrA",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Waimaw"
#         }
#     ],
#     "status": "OK"
# }
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Carmo do Cajuru -20.1842 -44.7711     78.58        59           0
# 1        Abu Samrah  35.3029  37.1841     78.12        27           0
# 2          Pāsighāt  28.0667  95.3333     71.98        92           0
# 3   Tiznit Province  29.5833  -9.5000     77.50        38           0
# 4             Belen  36.4891  36.2233     71.04        30           0
# 5  La Seyne-sur-Mer  43.0982   5.8847     74.25        61           0
# 6         Myitkyina  25.3833  97.4000     74.03        82           0
#
#    Wind Speed        Date       Hotel Name
# 0        8.19  1634994039  Carmo do Cajuru
# 1        3.31  1634994043            Suruj
# 2        2.98  1634994064         Pasighat
# 3        7.96  1634993488         Ouijjane
# 4        6.22  1634994157            Belen
# 5        1.99  1634994214           Toulon
# 6        1.01  1634994228        Myitkyina

# %%
# NOTE: Do not change any of the code in this cell
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
#Assign markers to a variable
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

#add markers
fig.add_layer(markers)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
